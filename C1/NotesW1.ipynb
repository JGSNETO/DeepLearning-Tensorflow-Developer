# %% [markdown]
# # **A new programming paradigm**
#
#
# *   Neural network is the base to standard recognition.
# *   A neural network is an implementation more advanced compared to machine learning, named as deep learning.
# *   Machine learning is the computer learn standard to differentiate things.
# *   API in TensorFlow(KERAS). Keras makes very easy define neural networks
# *   A neural network is basic a set of functions that can learn standards.

# %%
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
print('Most simples neural network!')
# Out:
# Most simples neural network!

# %% [markdown]
# # OBS
#
#
# *   `Dense` is used to define a layer of connected neurons
# *   Successive layers are defined using `Sequential`

# %% [markdown]
# # Basic Functions
#
# There is two basic important functions:
#
# *   Optimization: Peform guesses about which is the standard.
# *   Loss: Define how bad or how good a guess was and provide this information for optimization function.
#
# # Numpy
#
# Numpy is a python library that makes data representation more easier.

# %%
import numpy as np
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error') #Optimizer and Loss function
#Loss is the mean square error
#Optimizer is SGD: Stochastic Gradient Descent

#Represent the data

xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

#The training begins 
#Fit de Xs values in Ys values  
#Training loop(Guess, see how good..) =  500
model.fit(xs, ys, epochs=500)
#Make a prediction
print(model.predict([10.0]))

# %% [markdown]
# # OBS
#
# - Remember that neural networks deal with probabilities. So given the data that we fed the model with, it calculated that there is a very high probability that the relationship between x and y is y=2x-1, but with only 6 data points we can't know for sure. As a result, the result for 10 is very close to 19, but not necessarily 19.
#
# - As you work with neural networks, you'll see this pattern recurring. You will almost always deal with probabilities, not certainties, and will do a little bit of coding to figure out what the result is based on the probabilities, particularly when it comes to classification.
